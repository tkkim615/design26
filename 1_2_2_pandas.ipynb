# %%
data = [[5,1,10,8],
        [2,1,8,9],
        [3,2,1,10]]

# %%
import pandas as pd
df = pd.DataFrame(data)
df

# %%
df = pd.DataFrame(data, columns=['A', 'B', 'C', 'D'], index=['AA','BB','CC'])
df

# %%
df.head(2)

# %%
df.tail(1)

# %%
df[['B','D']]

# %%
df.loc[['AA','CC']]

# %%
df.iloc[0:2]

# %%
print(df.at['AA','B'])

# %%
print(df.iat[0,1])
